# %%
print("Hi")

import pandas as pd

l=[10,20,30,40,50]

df = pd.DataFrame(l)

print(df)

#two dimensional array
ll=[[10,20,30,40,50],[11,22,33,44,55,66]]

dfll = pd.DataFrame(ll)

print(dfll)
# Out:
# Hi
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
#     0   1   2   3   4     5
# 0  10  20  30  40  50   NaN
# 1  11  22  33  44  55  66.0

# %%
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}  #dictionaries

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42

# %%
from numpy.random import randn
import numpy as np

df = pd.DataFrame(randn(5,4),index= 'A B C D E'.split(),columns=['w','x','y','z'])

print(df)
# Out:
#           w         x         y         z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
df['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
df[['w','x']]
# Out:
#           W         X
# A  2.706850  0.628133
# B  0.651118 -0.319318
# C -2.018168  0.740122
# D  0.188695 -0.758872
# E  0.190794  1.978757

# %%
df['n']= df['w'] + df['x']
df
# Out:
#           W         X         Y         Z         n
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
 #axis=0 is for row and axis=1 is for column, inplace=True (drop will be permanant)
df.drop('n',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-dc4f7228592e> in <cell line: 2>()
#       1 #axis=0 is for row and axis=1 is for column, inplace=True (drop will be permanant)
# ----> 2 df.drop('n',axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
# ...

# %%
df
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
#Rows

df.loc['A']
# Out:
# W    0.302665
# X    1.693723
# Y   -1.706086
# Z   -1.159119
# Name: A, dtype: float64

# %%
#ilocate

df.iloc[1]
# Out:
# W   -0.134841
# X    0.390528
# Y    0.166905
# Z    0.184502
# Name: B, dtype: float64

# %%
#subset
df
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df.loc['C','Y']
# Out:
# 0.638787013499328

# %%
df.loc[['B','C'],['w','y']]
# Out:
#           w         y
# B  1.025984 -0.031579
# C  2.154846 -0.755325

# %%
#Conditional selection

df
# Out:
#           w         x         y         z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
df >0
# Out:
#        w      x      y      z
# A  False   True  False   True
# B   True  False  False   True
# C   True  False  False  False
# D   True  False   True   True
# E  False   True  False   True

# %%
df[df>0]
# Out:
#           w         x         y         z
# A       NaN  0.196800       NaN  0.000366
# B  1.025984       NaN       NaN  0.649826
# C  2.154846       NaN       NaN       NaN
# D  0.147027       NaN  0.558769  1.024810
# E       NaN  1.862864       NaN  0.610478

# %%
dd=df[df['w']>0]
print(dd)
print(type(dd))
df
# Out:
#           w         x         y         z
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# <class 'pandas.core.frame.DataFrame'>
#           w         x         y         z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
dd = df[df['w']>0]['y'] #fetching Y column for values greater than 0 in column W
print(dd)
# Out:
# B   -0.031579
# C   -0.755325
# D    0.558769
# Name: y, dtype: float64

# %%
df
# Out:
#           w         x         y         z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
dd = df[df['w']>0][['y','z']] #fetching Y column for values greater than 0 in column W
print(dd)
# Out:
#           y         z
# B -0.031579  0.649826
# C -0.755325 -0.346419
# D  0.558769  1.024810

# %%
dd2 = df[(df['w']>0) & df(df['y']>1)]
print(dd2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-b62ab0fb0b34> in <cell line: 1>()
# ----> 1 dd2 = df[(df['w']>0) & df(df['y']>1)]
#       2 print(dd2)
#
# TypeError: 'DataFrame' object is not callable

# %%
df
# Out:
#           w         x         y         z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
df.reset_index(inplace=True)
df
# Out:
#   index         w         x         y         z
# 0     A -0.993263  0.196800 -1.136645  0.000366
# 1     B  1.025984 -0.156598 -0.031579  0.649826
# 2     C  2.154846 -0.610259 -0.755325 -0.346419
# 3     D  0.147027 -0.479448  0.558769  1.024810
# 4     E -0.925874  1.862864 -1.133817  0.610478

# %%
df = pd.read_csv('data.csv')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.max_rows=1000
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
df.tail(2)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None
